# %% [markdown]
# # doc2vec学習済みモデルデータを使用する

# %%
import gensim

# %%
model = gensim.models.doc2vec.Doc2Vec.load('novel2vec.model')

# %%
model.most_similar(positive=['本丸'])
# Out:
# [('鎮守府', 0.9428099393844604),
#  ('町', 0.9225599765777588),
#  ('世界', 0.9113289713859558),
#  ('会社', 0.9099076986312866),
#  ('屋敷', 0.9055249691009521),
#  ('カルデア', 0.9024497270584106),
#  ('教会', 0.9000601172447205),
#  ('旅館', 0.8885697722434998),
#  ('事務所', 0.8871118426322937),
#  ('施設', 0.8863615393638611)]

# %%
model.most_similar(positive=['魔理沙'])
# Out:
# [('霊夢', 0.9331917762756348),
#  ('時雨', 0.9231343269348145),
#  ('アラン', 0.9227073192596436),
#  ('レオ', 0.9202938675880432),
#  ('瀬戸稔代', 0.9170882701873779),
#  ('アリス', 0.915237307548523),
#  ('エミヤ', 0.9136689901351929),
#  ('小田切', 0.9135326147079468),
#  ('ニック', 0.9127482771873474),
#  ('田崎', 0.911424994468689)]

# %%
model.most_similar(positive=['獅子王'])
# Out:
# [('今剣', 0.965623140335083),
#  ('ユーリ', 0.9606735706329346),
#  ('青江', 0.9579101204872131),
#  ('同田貫', 0.9578636884689331),
#  ('トド松', 0.9577581882476807),
#  ('ハリー', 0.9568682909011841),
#  ('神永', 0.9567629098892212),
#  ('小田切', 0.9559785723686218),
#  ('波多野', 0.9558809995651245),
#  ('蜻蛉切', 0.9548616409301758)]

# %%
model.most_similar(positive=['ヤバい'])
# Out:
# [('ヤバイ', 0.927619457244873),
#  ('やばい', 0.8147852420806885),
#  ('まずい', 0.7228056788444519),
#  ('ずるい', 0.7031792402267456),
#  ('マズイ', 0.6761728525161743),
#  ('気持ちいい', 0.67409348487854),
#  ('あかん', 0.662881076335907),
#  ('こわい', 0.6627122163772583),
#  ('なるほど', 0.6616227626800537),
#  ('ヤベェ', 0.6549128890037537)]

# %%
model.most_similar(positive=['クチュクチュ'])
# Out:
# [('ぴちゃぴちゃ', 0.9256782531738281),
#  ('ピチャピチャ', 0.9182119369506836),
#  ('グチュグチュ', 0.9131280183792114),
#  ('にちゃにちゃ', 0.8425256013870239),
#  ('ジュルジュル', 0.8150237798690796),
#  ('ジュポジュポ', 0.8050651550292969),
#  ('クチャクチャ', 0.7919228076934814),
#  ('くちゃくちゃ', 0.7901040315628052),
#  ('カチャカチャ', 0.7856903076171875),
#  ('ヌチャヌチャ', 0.7851128578186035)]

# %%
model.most_similar(positive=['くぱぁ'])
# Out:
# [('グググ', 0.7802480459213257),
#  ('めりめり', 0.764150857925415),
#  ('ツプリ', 0.762898325920105),
#  ('グリッ', 0.7567312717437744),
#  ('クチュリ', 0.7548766136169434),
#  ('みちみち', 0.7482854127883911),
#  ('ビッ', 0.7423003315925598),
#  ('ズプリ', 0.7376389503479004),
#  ('バリッ', 0.7310206890106201),
#  ('キュッキュ', 0.73056960105896)]

# %%
model.most_similar(positive=['うれしい', '泣く'], negative=['笑う'])
# Out:
# [('悲しい', 0.7828458547592163),
#  ('さみしい', 0.7670903205871582),
#  ('心細い', 0.7660514116287231),
#  ('嬉しい', 0.7657840847969055),
#  ('辛い', 0.760547399520874),
#  ('つらい', 0.7518221735954285),
#  ('可笑しい', 0.7516209483146667),
#  ('淋しい', 0.7475409507751465),
#  ('哀しい', 0.7413027882575989),
#  ('寂しい', 0.7387726902961731)]

# %%
model.most_similar(positive=['刀剣男士', '女'], negative=['男'])
# Out:
# [('艦娘', 0.9148839116096497),
#  ('使用人', 0.8912221193313599),
#  ('サーヴァント', 0.8801556825637817),
#  ('魔族', 0.877221941947937),
#  ('兄弟', 0.875967264175415),
#  ('英霊', 0.8656594753265381),
#  ('弟', 0.8649516701698303),
#  ('クラスメイト', 0.8640072345733643),
#  ('仲間', 0.8639708757400513),
#  ('遊女', 0.8562958240509033)]

# %%
model.most_similar(positive=['チョロ松', 'おそ子'], negative=['おそ松'])
# Out:
# [('神通', 0.8879706859588623),
#  ('川内', 0.8838447332382202),
#  ('霧島', 0.8780331611633301),
#  ('森山', 0.8707032203674316),
#  ('叢雲', 0.8702428936958313),
#  ('羽黒', 0.8701691627502441),
#  ('龍驤', 0.8699837327003479),
#  ('梓', 0.868868887424469),
#  ('アスカ', 0.8686018586158752),
#  ('中村', 0.868393063545227)]

# %%
model.most_similar(positive=['川内', 'アイドル'], negative=['那珂'])
# Out:
# [('ヒーロー', 0.8158879280090332),
#  ('パイロット', 0.8007603287696838),
#  ('革命軍', 0.7890353202819824),
#  ('警察官', 0.7872180938720703),
#  ('王族', 0.7838582992553711),
#  ('作曲家', 0.783134937286377),
#  ('テロリスト', 0.7792448997497559),
#  ('教師', 0.7765203714370728),
#  ('弁護士', 0.773236095905304),
#  ('スパイ', 0.7711319923400879)]

# %%
model.most_similar(positive=['忍者', '夕立'], negative=['川内'])
# Out:
# [('女子高生', 0.7601063251495361),
#  ('魔術師', 0.7596997022628784),
#  ('ヒロイン', 0.75954669713974),
#  ('殺し屋', 0.755066990852356),
#  ('猫', 0.7515921592712402),
#  ('亡霊', 0.7514910697937012),
#  ('女', 0.7514199018478394),
#  ('主人公', 0.7510868310928345),
#  ('リーダー', 0.7477249503135681),
#  ('武士', 0.7454527616500854)]

# %%
model.most_similar(positive=['山姥', '倶利伽羅'], negative=['宗近'])
# Out:
# [('スクール', 0.5600821375846863),
#  ('燭台', 0.5573146939277649),
#  ('1156', 0.5124794244766235),
#  ('おえる', 0.4726502001285553),
#  ('東亜', 0.46490710973739624),
#  ('尉殿', 0.46428394317626953),
#  ('鬼気', 0.45111948251724243),
#  ('Dieser', 0.4471295475959778),
#  ('TAS', 0.4429163932800293),
#  ('ぇっと', 0.43932321667671204)]

# %%
model.docvecs.most_similar([model.docvecs[1000]])
# Out:
# [('6906197', 0.9999998807907104),
#  ('6941223', 0.6282720565795898),
#  ('7002612', 0.6124913692474365),
#  ('6978427', 0.5993743538856506),
#  ('6971647', 0.5779218673706055),
#  ('6967953', 0.5744273662567139),
#  ('6947502', 0.5634235143661499),
#  ('6905223', 0.5545477867126465),
#  ('6907465', 0.5511783361434937),
#  ('7008107', 0.5498178005218506)]

# %%
model.docvecs.most_similar([model.docvecs['6960020']])
# Out:
# [('6960020', 1.0),
#  ('6962211', 0.6886913776397705),
#  ('6960630', 0.6673253774642944),
#  ('6955687', 0.6604750156402588),
#  ('6962888', 0.6589504480361938),
#  ('6984352', 0.6448876857757568),
#  ('6962131', 0.6406682133674622),
#  ('6959394', 0.6348965764045715),
#  ('6960526', 0.6329442262649536),
#  ('6951312', 0.6251099109649658)]

# %%
model.most_similar(positive=['時計', '場所'], negative=['時間'])
# Out:
# [('方角', 0.6598266363143921),
#  ('地図', 0.6472755670547485),
#  ('庭園', 0.647152304649353),
#  ('遺跡', 0.6431004405021667),
#  ('ガイドブック', 0.6320757865905762),
#  ('鏡', 0.6296912431716919),
#  ('天井', 0.6265701055526733),
#  ('中庭', 0.6251875162124634),
#  ('オアシス', 0.6211355924606323),
#  ('プラネタリウム', 0.6207263469696045)]

# %%
model.most_similar(positive=['唇', 'セックス'], negative=['キス'])
# Out:
# [('ペニス', 0.778108537197113),
#  ('性器', 0.7778970003128052),
#  ('闘い', 0.7713521718978882),
#  ('身体', 0.7697128653526306),
#  ('性交渉', 0.7694681882858276),
#  ('性行為', 0.7678791284561157),
#  ('陰茎', 0.7668424248695374),
#  ('乳首', 0.7657924890518188),
#  ('出会い', 0.7641059160232544),
#  ('男根', 0.7617620229721069)]

# %%
model.most_similar(positive=['敦', '現代'], negative=['明治'])
# Out:
# [('コナン', 0.7646421194076538),
#  ('影山', 0.7485178112983704),
#  ('沢村', 0.744890570640564),
#  ('赤司', 0.7426205277442932),
#  ('月島', 0.7413253784179688),
#  ('カラ松', 0.7408810257911682),
#  ('一騎', 0.7396073341369629),
#  ('芥川', 0.7389757037162781),
#  ('仗助', 0.736397385597229),
#  ('高尾', 0.7344973087310791)]

# %%
model.most_similar(positive=['太宰', '現代'], negative=['明治'])
# Out:
# [('赤井', 0.7817075252532959),
#  ('影山', 0.7703953981399536),
#  ('ヴィジョン', 0.7671884298324585),
#  ('神様', 0.7661879062652588),
#  ('スーパーマン', 0.764479398727417),
#  ('カミュ', 0.7633488774299622),
#  ('自分自身', 0.7630664706230164),
#  ('スモーキー', 0.7627824544906616),
#  ('アルミン', 0.7617053985595703),
#  ('三好', 0.7605339288711548)]

# %%
model.most_similar(positive=['乱歩', '現代'], negative=['明治'])
# Out:
# [('黒尾', 0.7538242340087891),
#  ('プロデューサー', 0.7511755228042603),
#  ('及川', 0.7510856986045837),
#  ('太宰', 0.7439517974853516),
#  ('カナメ', 0.7422207593917847),
#  ('赤井', 0.7359139919281006),
#  ('啓介', 0.7303615808486938),
#  ('菅原', 0.7300347089767456),
#  ('スーパーマン', 0.7290314435958862),
#  ('天童', 0.7267012000083923)]

# %%
model.most_similar(positive=['国木田', '現代'], negative=['明治'])
# Out:
# [('黒尾', 0.7145127654075623),
#  ('及川', 0.7061079740524292),
#  ('菅原', 0.6952929496765137),
#  ('舳丸', 0.6948506832122803),
#  ('シンタロー', 0.6946532726287842),
#  ('太宰', 0.6887642741203308),
#  ('涼介', 0.6878359317779541),
#  ('桃太郎', 0.6847847104072571),
#  ('プロデューサー', 0.684038519859314),
#  ('天童', 0.6816234588623047)]

# %%
model.most_similar(positive=['悲しみ'])
# Out:
# [('哀しみ', 0.9590884447097778),
#  ('憎しみ', 0.9036939740180969),
#  ('憎悪', 0.8821196556091309),
#  ('悲哀', 0.8704491257667542),
#  ('焦り', 0.8618566989898682),
#  ('焦燥', 0.8515974283218384),
#  ('怒り', 0.8360167741775513),
#  ('苦しみ', 0.8224100470542908),
#  ('悔恨', 0.8173078298568726),
#  ('疑心', 0.8128597736358643)]

# %%
model.most_similar(positive=['ロリ', '巨乳'], negative=['貧乳'])
# Out:
# [('牛', 0.621843695640564),
#  ('豚', 0.5681838989257812),
#  ('犬', 0.5675047039985657),
#  ('ウサギ', 0.5632370710372925),
#  ('狸', 0.5631312727928162),
#  ('熊', 0.5585710406303406),
#  ('鼠', 0.5551124811172485),
#  ('爬虫類', 0.5437599420547485),
#  ('ねずみ', 0.5427428483963013),
#  ('狩人', 0.5407041311264038)]

# %%
model.most_similar(positive=['友達', '恋人'])
# Out:
# [('家族', 0.9201378226280212),
#  ('友人', 0.9052004814147949),
#  ('彼氏', 0.9029746055603027),
#  ('友だち', 0.9006283283233643),
#  ('知り合い', 0.8926475048065186),
#  ('親友', 0.8905645608901978),
#  ('相棒', 0.8887679576873779),
#  ('女の子', 0.8882120251655579),
#  ('身内', 0.8857666254043579),
#  ('妻', 0.8857136964797974)]

# %%
model.most_similar(positive=['完全', '不完全'])
# Out:
# [('中途半端', 0.9110033512115479),
#  ('完璧', 0.9008808732032776),
#  ('明確', 0.8872247934341431),
#  ('見事', 0.886226236820221),
#  ('まとも', 0.8742809295654297),
#  ('緩やか', 0.8702829480171204),
#  ('妙', 0.8667787313461304),
#  ('静か', 0.8649251461029053),
#  ('控えめ', 0.8648726344108582),
#  ('従順', 0.8615698218345642)]

# %%
model.most_similar(positive=['大きい'])
# Out:
# [('強い', 0.8160519599914551),
#  ('速い', 0.7964994311332703),
#  ('固い', 0.7778379917144775),
#  ('硬い', 0.7755194306373596),
#  ('激しい', 0.7726991772651672),
#  ('重い', 0.7720433473587036),
#  ('おおきい', 0.7673165798187256),
#  ('熱い', 0.7659069299697876),
#  ('濃い', 0.7300402522087097),
#  ('小さい', 0.7113799452781677)]

# %%
model.most_similar(positive=['突く'])
# Out:
# [('穿つ', 0.898361086845398),
#  ('抉る', 0.879947304725647),
#  ('貫く', 0.85957932472229),
#  ('弄る', 0.8574050664901733),
#  ('えぐる', 0.852638840675354),
#  ('嬲る', 0.8470295667648315),
#  ('掻き回す', 0.8393361568450928),
#  ('暴く', 0.8372935056686401),
#  ('揺さぶる', 0.8311788439750671),
#  ('突き飛ばす', 0.8298511505126953)]
